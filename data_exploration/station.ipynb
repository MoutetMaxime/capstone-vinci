# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/consolidation-etalab-schema-irve-statique-v-2.3.1-20250129.csv')

df.head()
# Out:
# /var/folders/v5/_0ss5l5d6nz8d575gs5spbx40000gn/T/ipykernel_24456/93449805.py:1: DtypeWarning: Columns (12,18,19,20,21,22,24,29,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/consolidation-etalab-schema-irve-statique-v-2.3.1-20250129.csv')
#      nom_amenageur  siren_amenageur           contact_amenageur  \
# 0  SOLVEO ENERGIES      508886132.0  bornes@solveo-energies.com
# 1  SOLVEO ENERGIES      508886132.0  bornes@solveo-energies.com
# 2  SOLVEO ENERGIES      508886132.0  bornes@solveo-energies.com
# 3  SOLVEO ENERGIES      508886132.0  bornes@solveo-energies.com
# 4  SOLVEO ENERGIES      508886132.0  bornes@solveo-energies.com
#
#      nom_operateur           contact_operateur telephone_operateur  \
# 0  SOLVEO ENERGIES  bornes@solveo-energies.com      05 32 98 01 58
# 1  SOLVEO ENERGIES  bornes@solveo-energies.com      05 32 98 01 58
# 2  SOLVEO ENERGIES  bornes@solveo-energies.com      05 32 98 01 58
# ...

# %%
la_baule = 44055

df_la_baule = df[df["code_insee_commune"] == la_baule]


# Select only unique id_station_itinerance
df_la_baule = df_la_baule.drop_duplicates(subset=['id_station_itinerance'])
df_la_baule
# Out:
#                                 nom_amenageur  siren_amenageur  \
# 90917  Territoire d'Energie Loire Atlantique               NaN
# 90919  Territoire d'Energie Loire Atlantique               NaN
# 90921  Territoire d'Energie Loire Atlantique               NaN
# 90923                                  SYDELA      840290183.0
# 90925                                  SYDELA      840290183.0
# 90927                                  SYDELA      840290183.0
#
#         contact_amenageur      nom_operateur  \
# 90917                 NaN       Bouygues E&S
# 90919                 NaN       Bouygues E&S
# 90921                 NaN       Bouygues E&S
# 90923  contacts@sydela.fr  SPIE CITYNETWORKS
# 90925  contacts@sydela.fr  SPIE CITYNETWORKS
# 90927  contacts@sydela.fr  SPIE CITYNETWORKS
#
#                                        contact_operateur telephone_operateur  \
# 90917                             support@alizecharge.fr          0805021480
# ...
